# %% [markdown]
# <a href="https://colab.research.google.com/github/OPSdrag/Model_Traning_Practices/blob/main/boston_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##ML-**PROJECT**
# **BOSTON HOUSING PROJECT--**

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/dataprofessor/data/master/BostonHousing.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ###**Data preparation**

# %% [markdown]
# ####Data separation as x and y

# %%
y = df['medv']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
x = df.drop('medv',axis=1)
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %% [markdown]
# ####Data splitting

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=100)

# %%
x_train
# Out:
#          crim    zn  indus  chas     nox     rm    age     dis  rad  tax  \
# 379  17.86670   0.0  18.10     0  0.6710  6.223  100.0  1.3861   24  666
# 311   0.79041   0.0   9.90     0  0.5440  6.122   52.8  2.6403    4  304
# 157   1.22358   0.0  19.58     0  0.6050  6.943   97.4  1.8773    5  403
# 244   0.20608  22.0   5.86     0  0.4310  5.593   76.5  7.9549    7  330
# 56    0.02055  85.0   0.74     0  0.4100  6.383   35.7  9.1876    2  313
# ..        ...   ...    ...   ...     ...    ...    ...     ...  ...  ...
# 343   0.02543  55.0   3.78     0  0.4840  6.696   56.4  5.7321    5  370
# 359   4.26131   0.0  18.10     0  0.7700  6.112   81.3  2.5091   24  666
# 323   0.28392   0.0   7.38     0  0.4930  5.708   74.3  4.7211    5  287
# 280   0.03578  20.0   3.33     0  0.4429  7.820   64.5  4.6947    5  216
# 8     0.21124  12.5   7.87     0  0.5240  5.631  100.0  6.0821    5  311
#
#      ptratio       b  lstat
# 379     20.2  393.74  21.78
# 311     18.4  396.90   5.98
# ...

# %%
x_test
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 198   0.03768  80.0   1.52     0  0.404  7.274   38.3  7.3090    2  329
# 229   0.44178   0.0   6.20     0  0.504  6.552   21.4  3.3751    8  307
# 502   0.04527   0.0  11.93     0  0.573  6.120   76.7  2.2875    1  273
# 31    1.35472   0.0   8.14     0  0.538  6.072  100.0  4.1750    4  307
# 315   0.25356   0.0   9.90     0  0.544  5.705   77.7  3.9450    4  304
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 166   2.01019   0.0  19.58     0  0.605  7.929   96.2  2.0459    5  403
# 401  14.23620   0.0  18.10     0  0.693  6.343  100.0  1.5741   24  666
# 368   4.89822   0.0  18.10     0  0.631  4.970  100.0  1.3325   24  666
# 140   0.29090   0.0  21.89     0  0.624  6.174   93.6  1.6119    4  437
# 428   7.36711   0.0  18.10     0  0.679  6.193   78.1  1.9356   24  666
#
#      ptratio       b  lstat
# 198     12.6  392.20   6.62
# 229     17.4  380.34   3.76
# ...

# %% [markdown]
# ### **MODEL ACTUAL BUILDING**

# %% [markdown]
# #### **Linear Regression**

# %% [markdown]
# #####*Traning* model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #####Applying the model to make a prediction

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
print(y_lr_train_pred)
# Out:
# [17.1751752  26.80189827 32.385352   16.04200939 24.76473869 16.4346134
#   4.01170984 22.72827789 23.66963778 35.10827099 30.9778149  13.45709423
#  25.17925999 16.60249088 30.72676784 18.18920532 26.09900394  8.80519962
#  17.64514981 20.15169255 20.85628448 24.67696555 21.31244099 15.66780071
#  20.70637689 18.4604944  20.68120347 21.3034913  28.12930046 18.49520639
#  28.16662405 19.33375452 29.53704278 40.50685103 17.59565323 26.98111856
#  21.76297434 24.68488507 14.41988234  8.31068511 14.0967307  28.48269774
#  30.07513698 17.63978619 24.51699582 28.30515143 20.25963634 31.0879148
#  18.15361701 40.1119927  22.06583941 23.71408543 19.10357934 30.10273349
#  24.74285588 17.38397809 20.54872085 14.74389569 19.39339427 31.83315778
#  26.42142487 13.91117291 22.93058079 24.95935882 15.50103102 27.36419987
#  16.71232158 15.1458574  27.82479888 27.30005405 21.38627205 34.27426872
#  28.25277613 24.41593448 26.47972465 20.10733514 31.75737278 22.21081987
# ...

# %%
y_lr_test_pred
# Out:
# array([34.4081095 , 31.18524626, 22.31286141, 17.88613877, 20.43572131,
#        26.14444413, 26.21920244, 23.57978445, 22.41577853, 19.51182817,
#        26.86691495, 17.20411302, 20.68511041, 15.67921778, 41.69912781,
#        20.2946735 , 28.99258631, 19.06413492, 32.48035595, 41.13627224,
#        34.64732462, 16.38997909, 20.42215729, 18.05324255, 13.38743087,
#        12.64800748, 27.45930237, 20.30199107, 18.78954741, 20.24950994,
#        15.60161419, 24.38040555, 38.95651978, 24.7184131 , 31.26791961,
#        28.26279775, 15.84707127, 14.76661568, 16.79024244, 23.23674899,
#        22.85417065, 23.48976177, 14.16818173, 21.42613087, 32.38362329,
#        26.7881669 , 19.37574824, 15.27894103, 17.21175121, 12.91591919,
#        21.84063224, 20.25050371, 23.65622638, 23.9608324 , 11.94749102,
#        14.49718052, 24.69872363, 34.18169066, 10.30437821, 21.04686616,
#        17.96204214, 19.76593459, 17.45231513, 29.982971  , 20.73183476,
# ...

# %% [markdown]
# **Evaluate model perfomance**

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print("LR MSE (TRAIN):",lr_train_mse)
print("LR R2 (TRAIN):",lr_train_r2)
print("LR MSE (TEST):",lr_test_mse)
print("LR R2 (TEST):",lr_test_r2)
# Out:
# LR MSE (TRAIN): 21.649376911833603
# LR R2 (TRAIN): 0.7337332767917557
# LR MSE (TEST): 23.61699410056368
# LR R2 (TEST): 0.75550330868713

# %%
lr_results = pd.DataFrame(["Linear regression",lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Traning Mse', 'Traning R2', 'Test Mse', 'Test R2']

# %%
lr_results
# Out:
#               Method Traning Mse Traning R2   Test Mse   Test R2
# 0  Linear regression   21.649377   0.733733  23.616994  0.755503

# %% [markdown]
# #### **Random Forest**

# %% [markdown]
# #####Traning the model

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# #####Applying the model to make prediction

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# #####Evaluate model perfomance

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(["Random Forest",rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Traning Mse', 'Traning R2', 'Test Mse', 'Test R2']

# %%
rf_results
# Out:
#           Method Traning Mse Traning R2   Test Mse   Test R2
# 0  Random Forest   19.294598   0.762695  23.259039  0.759209

# %% [markdown]
# ###**Model Comparison**

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)
df_models
# Out:
#               Method Traning Mse Traning R2   Test Mse   Test R2
# 0  Linear regression   21.649377   0.733733  23.616994  0.755503
# 0      Random Forest   19.294598   0.762695  23.259039  0.759209

# %% [markdown]
# #**Data Visualization of RESULTS**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred, alpha=0.5)

r = np.polyfit(y_train,y_lr_train_pred, 1)
p =  np.poly1d(r)

plt.plot(y_train,p(y_train), '#f8533D')
plt.ylabel("predict Logs")
plt.xlabel("Experimental Logs")
# Out:
# Text(0.5, 0, 'Experimental Logs')

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=y_test, y=y_lr_test_pred,alpha=0.5)

z = np.polyfit(y_test,y_lr_test_pred, 1)
p=np.poly1d(z)

plt.plot(y_test,p(y_test), '#f8533D')
plt.ylabel("predict logs")
plt.ylabel("Experimental logs")
# Out:
# Text(0, 0.5, 'Experimental logs')

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_rf_train_pred,alpha=0.5)

t = np.polyfit(y_train,y_rf_train_pred,1)
p = np.poly1d(t)

plt.plot(y_train,p(y_train), '#f8533D')
plt.ylabel("predict logs")
plt.ylabel("Experimental logs")
# Out:
# Text(0, 0.5, 'Experimental logs')

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=y_test, y=y_rf_test_pred,alpha=0.5)

t = np.polyfit(y_test,y_rf_test_pred,1)
p = np.poly1d(t)

plt.plot(y_test,p(y_test), '#f8533D')
plt.ylabel("predict logs")
plt.ylabel("Experimental logs")
# Out:
# Text(0, 0.5, 'Experimental logs')
